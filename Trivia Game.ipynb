# %% [markdown]
# # H&G Trivia🐹
# ### H&G Trivia by Aaron D'Souza

# %%
import random
import numpy as np

# %%
class Stack:
    def __init__(self):
        """atribiutes"""
        self.stack=[]
        self.n = 0
        self.top = None
    def add(self,item):
        """
        Add items to stack
        
        """
        self.stack.append(item)
        self.n +=1
        self.top= len(self.stack) -1
    def pop(self):
        """return top item/last item placed"""
        if self.n==0:
            return 'The Stack is empty'
        else:
            self.result=self.stack[self.top]
            self.stack=self.stack[:-1]
            self.n-=1
            self.top = self.n - 1
            return self.result
    def is_empty(self):
        """Check if stack is empty"""
        if self.n==0:
            return True
        else:
            return False
    def size(self):
        """
        return the size of the stack
        """
        return self.n
    
    def peak(self):
        """
        peak at next item to be removed from stack
        """
        return self.stack[self.top]

# %%
class Queue:
    def __init__(self):
        self.queue=[]
        self.n = 0
        self.bottom = 0
    def add(self, item):
        """
        add an element to queue
        """
        self.queue.append(item)
        self.n +=1
    def pop(self,item):
        """
        return top item/first item placed
        """
        if self.n==0:
            return 'The Queue is empty'
        else:
            self.result = self.queue[self.bottom]
            self.queue = self.queue[1:]
            self.n-=1
    def is_empty(self):
        """Check if the Queue is empty"""
        if self.n==0:
            return True
        else:
            return False
    def size(self):
        """check how many elements remaining in queue"""
        return self.n
    def peak(self):
        """check the next item to be removed"""
        return self.queue[self.top]

# %%
Geography_Trivia = {
    'q1':{
        'q': "The highest mountain on Earth, Mount Everest, is located in which mountain range?",
        'options': ['Rocky Mountains', 'Alps','Himalayas','Andes'],
        'ans': 'Himalayas'},
    'q2':{
        'q': "Busan is the second most populous city in what country?",
        'options': ['Russia', 'Algeria','South Korea','India'],
        'ans': 'South Korea'},
    'q3':{
        'q': "The deepest trench in the world, the Mariana Trench, is located in which ocean?",
        'options': ['Pacific Ocean', 'Atlantic Ocean','Indian Ocean','Arctic Ocean'],
        'ans': 'Pacific Ocean'},
    'q4':{
        'q': "“Oro y Plata” (Spanish for gold and silver) is the motto of which U.S. state?",
        'options': ['California', 'Nevada','Montana','New Mexico'],
        'ans': 'Montana'},
    'q5':{
        'q': "What country is home to the longest canal in the world?",
        'options': ['Panama', 'China','Egypt','Nigeria'],
        'ans': 'China'},
    'q6':{
        'q': "What is the largest contenent?",
        'options': ['Asia', 'Antarctica','Austrialia','South America'],
        'ans': 'Asia'}
}

# %%
History_Trivia = {
    'q1':{
        'q': "On Jan. 27, 1967, a flash fire swept through the command module of which Apollo mission?",
        'options': ['5', '3','1','4'],
        'ans': '1'},
    'q2':{
        'q': "The signing of the Paris Peace Accords officially ended direct U.S. involvement in which War?",
        'options': ['World War 1', 'Vietnam War','World War 2','Revolutionary War'],
        'ans': 'South Korea'},
    'q3':{
        'q': "Which Apollo 11 crew member did not walk on the moon?",
        'options': ['Micheal Collins', 'Neil Armstrong','Buzz Aldrin', 'none of them'],
        'ans': 'Buzz Aldrin'},
    'q4':{
        'q': "“The Treaty of Ghent was the peace treaty that ended which war?",
        'options': ['World War 1', 'The war of 1812','World War 2','Sino-Japanese War'],
        'ans': 'The war of 1812'},
    'q5':{
        'q': "The Ford Mustang was introduced the public at at the New York World’s Fair in what year?",
        'options': ['1964', '1974','1982','1954'],
        'ans': '1964'},
    'q6':{
        'q': "Who was the only bachelor to serve as president of the United States?",
        'options': ['James Buchanan', 'Donald Trump','Chester A. Arthur','Ulysses S. Grant'],
        'ans': 'James Buchanan'
    }
}

# %%
#game cycle
gameOn= True
while gameOn:
    """do you want to continue/start the game"""
    if_cont = input('Do you want to continue/start the game? [Y/N]')
    if if_cont=='Y' or if_cont=='y':
        gameOn=True
    elif if_cont=='N' or if_cont =='n':
        gameOn=False
        break
    else:
        print('you failed')
        break
    """what category do you want"""
    topic = input('Wich genre of trivia would you like to play (A)History (B)Geography')
    questions = Stack()
    decided = False
    category = {}
    while decided==False:
        if topic=='A' or topic=='a':
            decided=True
            category = History_Trivia
            print("You have chosen your category")
        elif topic=='B' or topic=='b':
            decided=True
            category = Geography_Trivia
            print("you have chosen your category")
        else:
            print("INVALID INPUT ERROR ERROR ERROR ERROR ERROR ERROR ERROR ERROR ERROR ERROR ERROR ERROR ERROR")
            topic = input('Wich genre of trivia would you like to play (A)History (B)Geography')
    """Setting up questions"""
    keys=list(category)
    random.shuffle(keys)
    for key in keys:
        questions.add(category[key])
    game = False
    play= True
    score = 0

    while play:
        if questions.size()== 0:
            if score ==5:
                rank = "master"
            elif score ==6:
                rank = "Ai" 
            elif score ==4:
                rank = "human"
            elif score ==3:
                rank = "standard"
            elif score <=2 and score>0:
                rank = "Rokkie"
            elif score==0:
                rank = "nothing"
            print("Your game has ended "+ rank + " with a score of "+ str(score))
            
            #break from game
            play=False
            break
        """display question"""
        ques_temp = questions.pop()
        q = ques_temp['q']
        options= ques_temp['options']
        ans = ques_temp['ans']
        
        """display opt.""" 
        print('\n')
        print('Q:' + q)
        print('A.' + options[0])
        print('B.' + options[1])
        print('C.' + options[2])
        print('D.' + options[3])
        
        answer = input('Your Answer: ')
        user_answer = None
        
        """setting user options"""
        if answer=="A" or answer=="a":
            user_answer = options[0]
        elif answer=="B" or answer=="b":
            user_answer= options[1]
        elif answer=="C" or answer=="c":
            user_answer = options[2]
        elif answer=="D" or answer=="d":
            user_answer = options[3]
            
        if user_answer== ans:
            score += 1
            print("You got the question corect")
            print("\n")
            print("Your score so far is " + str(score))
        else:
            print("Boo YOU GOT THE QUESTION WRONG WRONG")
# Out:
# Do you want to continue/start the game? [Y/N]y
# Wich genre of trivia would you like to play (A)History (B)Geographyb
# you have chosen your category
#
#
# Q:What is the largest contenent?
# A.Asia
# B.Antarctica
# C.Austrialia
# D.South America
# Your Answer: a
# You got the question corect
#
#
# Your score so far is 1
#
#
# Q:Busan is the second most populous city in what country?
# A.Russia
# B.Algeria
# C.South Korea
# D.India
# Your Answer: b
# Boo YOU GOT THE QUESTION WRONG WRONG
#
#
# Q:What country is home to the longest canal in the world?
# A.Panama
# B.China
# C.Egypt
# D.Nigeria
# Your Answer: b
# You got the question corect
#
#
# Your score so far is 2
#
#
# Q:“Oro y Plata” (Spanish for gold and silver) is the motto of which U.S. state?
# A.California
# B.Nevada
# C.Montana
# D.New Mexico
# Your Answer: b
# Boo YOU GOT THE QUESTION WRONG WRONG
#
#
# Q:The highest mountain on Earth, Mount Everest, is located in which mountain range?
# A.Rocky Mountains
# B.Alps
# ...

# %%
ques= Stack()
keys=list(History_Trivia)
random.shuffle(keys)
keys

# %%
for key in keys:
    ques.add(History_Trivia[key])

# %%
ques.peak()
